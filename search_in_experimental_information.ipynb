# %% [markdown]
# # Import the libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read the pickle file

# %%
experimental_data = pd.read_pickle("parquets/experimental_conditions.pkl")

# %%
experimental_data
# Out:
#     Slide_Name Well_ID   Strain Bacteria_Type  \
# 0      Slide_1     w_1  Rev10a2          rods
# 1      Slide_1     w_2  Rev10a2          rods
# 2      Slide_1     w_3  Rev10a2          rods
# 3      Slide_1     w_4  Rev10a2          rods
# 4      Slide_1     w_5  Rev10a2          rods
# ..         ...     ...      ...           ...
# 290  Sample_11     w_1  Rev10a2          None
# 291  Sample_12     w_1  Rev10a2          None
# 292          1     w_1  Rev10a2          None
# 293          2     w_1  Rev10a2          None
# 294          3     w_1  Rev10a2          None
#
#      Bacterial_GFP_constitutive_expression Experiment_Ref Cell_Line  \
# 0                                     True           None      None
# 1                                     True           None      None
# 2                                     True           None      None
# 3                                     True           None      None
# ...

# %%
experimental_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 69 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Slide_Name                                 295 non-null    object
#  1   Well_ID                                    295 non-null    object
#  2   Strain                                     295 non-null    category
#  3   Bacteria_Type                              295 non-null    category
#  4   Bacterial_GFP_constitutive_expression      295 non-null    bool
#  5   Experiment_Ref                             295 non-null    object
#  6   Cell_Line                                  295 non-null    category
#  7   Biological_Replicate                       295 non-null    category
#  8   Technical_Replicate                        295 non-null    category
#  9   Ampicillin_Concentration                   295 non-null    int64
# ...

# %% [markdown]
# # Get information relative the samples

# %% [markdown]
# ## Age of the cultures and infection time

# %%
age_data = experimental_data.iloc[:,np.r_[0:12, 17, 67:69]]

# %%
age_data.tail(10)
# Out:
#     Slide_Name Well_ID   Strain Bacteria_Type  \
# 285   Sample_6     w_1  Rev10a2          None
# 286   Sample_7     w_1  Rev10a2          None
# 287   Sample_8     w_1  Rev10a2          None
# 288   Sample_9     w_1  Rev10a2          None
# 289  Sample_10     w_1  Rev10a2          None
# 290  Sample_11     w_1  Rev10a2          None
# 291  Sample_12     w_1  Rev10a2          None
# 292          1     w_1  Rev10a2          None
# 293          2     w_1  Rev10a2          None
# 294          3     w_1  Rev10a2          None
#
#      Bacterial_GFP_constitutive_expression Experiment_Ref Cell_Line  \
# 285                                   True             E5      BeWo
# 286                                   True             E5      BeWo
# 287                                   True             E6     HBMEC
# 288                                   True             E6     HBMEC
# 289                                   True             E5      BeWo
# ...

# %%
age_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Slide_Name                             295 non-null    object
#  1   Well_ID                                295 non-null    object
#  2   Strain                                 295 non-null    category
#  3   Bacteria_Type                          295 non-null    category
#  4   Bacterial_GFP_constitutive_expression  295 non-null    bool
#  5   Experiment_Ref                         295 non-null    object
#  6   Cell_Line                              295 non-null    category
#  7   Biological_Replicate                   295 non-null    category
#  8   Technical_Replicate                    295 non-null    category
#  9   Ampicillin_Concentration               295 non-null    int64
# ...

# %% [markdown]
# ### Search for a specific sample from the sample list

# %%
set(age_data['Slide_Name'].tolist())
# Out:
# {'1',
#  '2',
#  '3',
#  'Sample_1',
#  'Sample_10',
#  'Sample_11',
#  'Sample_12',
#  'Sample_2',
#  'Sample_3',
#  'Sample_4',
#  'Sample_5',
#  'Sample_6',
#  'Sample_7',
#  'Sample_8',
#  'Sample_9',
#  'Slide_1',
#  'Slide_10',
#  'Slide_11',
#  'Slide_12',
#  'Slide_13',
#  'Slide_14',
#  'Slide_15',
#  'Slide_16',
#  'Slide_17',
#  'Slide_18',
#  'Slide_19',
#  'Slide_2',
#  'Slide_20',
#  'Slide_21',
#  'Slide_22',
#  'Slide_23',
#  'Slide_24',
#  'Slide_25',
#  'Slide_26',
#  'Slide_27',
#  'Slide_28',
#  'Slide_29',
#  'Slide_3',
#  'Slide_30',
#  'Slide_31',
#  'Slide_32',
#  'Slide_33',
#  'Slide_34',
#  'Slide_35',
#  'Slide_4',
#  'Slide_5',
#  'Slide_6',
#  'Slide_7',
#  'Slide_8',
#  'Slide_9'}

# %%
age_data.iloc[np.r_[age_data.loc[age_data['Slide_Name'].str.contains('Sample_')].index, 292:295], :]
# Out:
#     Slide_Name Well_ID   Strain Bacteria_Type  \
# 280   Sample_1     w_1  Rev10a2          None
# 281   Sample_2     w_1  Rev10a2          None
# 282   Sample_3     w_1  Rev10a2          None
# 283   Sample_4     w_1  Rev10a2          None
# 284   Sample_5     w_1  Rev10a2          None
# 285   Sample_6     w_1  Rev10a2          None
# 286   Sample_7     w_1  Rev10a2          None
# 287   Sample_8     w_1  Rev10a2          None
# 288   Sample_9     w_1  Rev10a2          None
# 289  Sample_10     w_1  Rev10a2          None
# 290  Sample_11     w_1  Rev10a2          None
# 291  Sample_12     w_1  Rev10a2          None
# 292          1     w_1  Rev10a2          None
# 293          2     w_1  Rev10a2          None
# 294          3     w_1  Rev10a2          None
#
#      Bacterial_GFP_constitutive_expression Experiment_Ref Cell_Line  \
# 280                                   True             E7      BeWo
# 281                                   True             E7      BeWo
# ...
